# %% [markdown]
# **Dependencies**

# %% [markdown]
# - [gzip](https://anaconda.org/conda-forge/m2-gzip)
# - os
# - shutil
# - [Nibabel](https://anaconda.org/conda-forge/nibabel)
# - [ImageIO](https://anaconda.org/conda-forge/imageio)

# %%
import gzip
import os
import shutil
import nibabel as nib
import imageio

# %% [markdown]
# **Unzipping GZ Files to Nifti**

# %% [markdown]
# *Note:* Before running this code you must extract the dataset from the tar file and update the paths. "final_dataset_path" is the path to your new folder that will hold the png images.

# %%
dataset_path = 'D:/BraTS'

for subdir in os.listdir(dataset_path):
    subdir_path = os.path.join(dataset_path,subdir)
    
    if os.path.isdir(subdir_path):
        for gzip_path in os.listdir(subdir_path):
                gzip_file = os.path.join(subdir_path,gzip_path)

                if os.path.isfile(gzip_file):
                    with gzip.open(gzip_file,'rb') as f_in:
                        output_path = os.path.splitext(gzip_file)[0]
                        
                        with open(output_path,'wb') as f_out:
                            shutil.copyfileobj(f_in,f_out)

# %% [markdown]
# **Converting Nifti to PNG**

# %%
final_dataset_path = 'D:/BraTS_FINAL'
original_dataset_path = 'D:/BraTS'

for instance_dir in os.listdir(original_dataset_path):
    
    original_instance_dir_path = os.path.join(original_dataset_path,instance_dir)
    
    if os.path.isdir(original_instance_dir_path):
        final_instance_dir_path = os.path.join(final_dataset_path,instance_dir)
        os.mkdir(final_instance_dir_path)
        
        for nifti_file in os.listdir(original_instance_dir_path):
            original_nifti_file = os.path.join(original_instance_dir_path,nifti_file)
            
            if ((os.path.isfile(original_nifti_file)) and (os.path.splitext(original_nifti_file)[1].lower() == '.nii')):
                png_file = os.path.splitext(nifti_file)[0]
                final_png_file = os.path.join(final_instance_dir_path,png_file)
                os.mkdir(final_png_file)
                
                nii_img = nib.load(original_nifti_file)
                img_fdata = nii_img.get_fdata()
                
                slice_number = nii_img.shape[2]
                
                for z in range(slice_number):
                    slice_img = img_fdata[:,:,z]
                    
                    slice_png_filename = png_file + '_slice' + str(z) + '.png'
                    final_slice_png_file = os.path.join(final_png_file,slice_png_filename)
                    imageio.imwrite(final_slice_png_file, slice_img)
# Out:
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0, 1]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 762.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 946.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1035.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1039.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1047.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1201.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1179.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1189.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1200.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1268.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1232.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1263.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1280.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1289.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1395.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1344.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1354.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1398.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1453.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1470.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1426.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1478.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1459.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1445.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1620.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1531.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1562.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1516.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1567.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1567.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1566.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1612.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1606.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1650.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1600.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1604.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1575.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 1653.0]. Convert image to uint8 prior to saving to suppress this warning.
# Lossy conversion from float64 to uint8. Range [0.0, 